# %% [markdown]
# # Guided Capstone Step 3 Exploratory Data Analysis

# %% [markdown]
# This is the third step in the Data Science Method. We introduced this topic in the last subunit. With Data Wrangling out of the way we can progress to the Exploratory Data Analysis section. In this exercise, you will learn to build data profiles and plots, including relationship plot and data correlation plot. You will also implement k-means clustering, complete clusters, and update data frame as a CSV file. Let's get started!
#
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   Data Wrangling
#   * Data Collection
#    * Data Organization
#   * Data Definition
#   * Data Cleaning
#
# 3.   **Exploratory Data Analysis**
#  * Build data profile tables and plots
#         - Outliers & Anomalies
#  * Explore data relationships
#  * Identification and creation of features
#
# 4.   Pre-processing and Training Data Development
#   * Create dummy or indicator features for categorical variables
#   * Standardize the magnitude of numeric features
#   * Split into testing and training datasets
#   * Apply scaler to the testing set
# 5.   Modeling
#   * Fit Models with Training Data Set
#   * Review Model Outcomes — Iterate over additional models as needed.
#   * Identify the Final Model
#
# 6.   Documentation
#   * Review the Results
#   * Present and share your findings - storytelling
#   * Finalize Code
#   * Finalize Documentation

# %% [markdown]
# **<font color='teal'> Start by loading the necessary packages as we did in step 2 and printing out our current working directory just to confirm we are in the correct project directory. </font>**

# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

os.getcwd()
# Out:
# 'C:\\Users\\carl_\\Desktop\\Springboard\\Guided Capstone\\Step 3\\Data'

# %% [markdown]
# **<font color='teal'> If you need to change your path refer back to step 2 on how to do that. Then load the csv file you created in step 2, remember it should be saved inside your data subfolder and print the first five rows.</font>**

# %%
path="C:\\Users\\carl_\\Desktop\\Springboard\\Guided Capstone\\Step 3\\Data"
os.chdir(path)
os.getcwd()

df = pd.read_csv('step2_output.csv')

# %% [markdown]
# # Build data profile tables and plots

# %% [markdown]
# **<font color='teal'> Print out the summary stats table transposed to fit on the screen using the `describe()` function.</font>**

# %%
df.describe()
# Out:
#        Unnamed: 0   summit_elev  vertical_drop     base_elev       trams  \
# count  330.000000    330.000000     330.000000    330.000000  330.000000
# mean   164.500000   4591.818182    1215.427273   3374.000000    0.172727
# std     95.407023   3735.535934     947.864557   3117.121621    0.559946
# min      0.000000    315.000000      60.000000     70.000000    0.000000
# 25%     82.250000   1403.750000     461.250000    869.000000    0.000000
# 50%    164.500000   3127.500000     964.500000   1561.500000    0.000000
# 75%    246.750000   7806.000000    1800.000000   6325.250000    0.000000
# max    329.000000  13487.000000    4425.000000  10800.000000    4.000000
#
#         fastEight   fastSixes   fastQuads        quad     triple  ...  \
# count  330.000000  330.000000  330.000000  330.000000  330.00000  ...
# mean     0.003030    0.184848    1.018182    0.933333    1.50000  ...
# std      0.055048    0.651685    2.198294    1.312245    1.61913  ...
# min      0.000000    0.000000    0.000000    0.000000    0.00000  ...
# 25%      0.000000    0.000000    0.000000    0.000000    0.00000  ...
# 50%      0.000000    0.000000    0.000000    0.000000    1.00000  ...
# 75%      0.000000    0.000000    1.000000    1.000000    2.00000  ...
# max      1.000000    6.000000   15.000000    8.000000    8.00000  ...
#
#        Snow Making_ac  daysOpenLastYear    yearsOpen  averageSnowfall  \
# count      284.000000        279.000000   329.000000       316.000000
# mean       174.873239        115.103943    63.656535       185.316456
# std        261.336125         35.063251   109.429928       136.356842
# min          2.000000          3.000000     6.000000        18.000000
# 25%         50.000000         97.000000    50.000000        69.000000
# 50%        100.000000        114.000000    58.000000       150.000000
# 75%        200.500000        135.000000    69.000000       300.000000
# max       3379.000000        305.000000  2019.000000       669.000000
#
#        AdultWeekday  AdultWeekend  projectedDaysOpen  NightSkiing_ac  \
# count    330.000000    329.000000         283.000000      330.000000
# mean      57.916957     65.535363         120.053004       56.890909
# std       23.898798     23.499631          31.045963       93.464882
# min       15.000000     17.000000          30.000000        0.000000
# 25%       43.000000     48.000000         100.000000        0.000000
# 50%       57.916957     62.000000         120.000000       27.000000
# 75%       67.000000     79.000000         139.500000       83.750000
# max      179.000000    179.000000         305.000000      650.000000
#
#           calctot   diff
# count  330.000000  330.0
# mean     8.266667    0.0
# std      5.798683    0.0
# min      0.000000    0.0
# 25%      5.000000    0.0
# 50%      7.000000    0.0
# 75%     10.000000    0.0
# max     41.000000    0.0
#
# [8 rows x 27 columns]

# %% [markdown]
# **<font color='teal'> Histograms are an excellent way to review the range and density of values for each numeric features in your data set and build data profiles. Plot the histograms for all numeric features and adjust the bins size to 25.</font>**

# %%
df.hist(bins=25, figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002448B61E8C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244AFC099C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244AFC21948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244AFC327C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244AFC407C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000244AFE1DA48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244AFE33F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244AFE44D08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244AFE47B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244AFE5BB08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000244AFE84E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244AFE98748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244AFEAF848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244AFEC6988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244AFEDCA88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000244AFF00B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244AFF31CC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244AFF69D48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244AFFA0E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244AFFD9F88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000244B00170C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244B004F1C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244B0087288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244B00C0388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244B00F8488>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000244B01305C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244B0169708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244B01A2808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244B01D9948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000244B0212B48>]],
#       dtype=object)

# %% [markdown]
# Look for similarities in the features that may indicate that they are duplicates or highly correlated features. Make a note of your findings and any other interesting insights you find about these numeric features.

# %% [markdown]
# **<font color='teal'> Okay, now you should be getting a sense for what the data look like. Let's create a barplot for the categorical features `Region` and `state` where the heights of the bars are the counts of each level in that variable. </font>**

# %% [markdown]
# **<font color='teal'>State Levels Plot</font>**

# %%
# Uncomment the following code to get your visualization started 
f, ax = plt.subplots(figsize=(10, 10))

# In the following brackets, we want the value_counts() of the states 
x = pd.DataFrame(df.state.value_counts())

# Get the state names by calling list() on the x.index
names = list(x.index)

# Get the values by plugging x.state into the list() function
values = list(x.state)

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above. 
sns.barplot(x=values, y=names, palette="RdBu_r")

# %% [markdown]
# **<font color='teal'>Region Levels Plot</font>**

# %%
# Now do the same for regions! 
# Uncomment the following code to get your visualization started 
f, ax = plt.subplots(figsize=(10, 10))

# In the following brackets, we want the value_counts() of the states 
x = pd.DataFrame(df.Region.value_counts())

# Get the state names by calling list() on the x.index
names = list(x.index)

# Get the values by plugging x.state into the list() function
values = list(x.Region)

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above. 
sns.barplot(x=values, y=names, palette="RdBu_r")

# %% [markdown]
# By reviewing the State and Regions counts plots you should notice that the Region feature is nearly identical to the state and therfore we can remove from the dataframe.**<font color='teal'> Remove the `Region` column using the drop function.</font>**

# %%
df['Region'].drop
del df['Region']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         330 non-null    int64
#  1   Name               330 non-null    object
#  2   state              330 non-null    object
#  3   summit_elev        330 non-null    int64
#  4   vertical_drop      330 non-null    int64
#  5   base_elev          330 non-null    int64
#  6   trams              330 non-null    int64
#  7   fastEight          330 non-null    float64
#  8   fastSixes          330 non-null    int64
#  9   fastQuads          330 non-null    int64
#  10  quad               330 non-null    int64
#  11  triple             330 non-null    int64
#  12  double             330 non-null    int64
#  13  surface            330 non-null    int64
#  14  total_chairs       330 non-null    int64
#  15  Runs               326 non-null    float64
#  16  TerrainParks       279 non-null    float64
#  17  LongestRun_mi      325 non-null    float64
#  18  SkiableTerrain_ac  327 non-null    float64
#  19  Snow Making_ac     284 non-null    float64
#  20  daysOpenLastYear   279 non-null    float64
#  21  yearsOpen          329 non-null    float64
#  22  averageSnowfall    316 non-null    float64
#  23  AdultWeekday       330 non-null    float64
#  24  AdultWeekend       329 non-null    float64
#  25  projectedDaysOpen  283 non-null    float64
#  26  NightSkiing_ac     330 non-null    float64
#  27  calctot            330 non-null    float64
#  28  diff               330 non-null    float64
# dtypes: float64(15), int64(12), object(2)
# memory usage: 74.9+ KB

# %% [markdown]
# ## Anamolies & Outliers - Review boxplots

# %% [markdown]
# **<font color='teal'> Print boxplot for every column</font>**
#
# Hint: you'll see the methodology here in this article on Exploratory Data Analysis [here](nce-method-dsm-exploratory-data-analysis-bc84d4d8d3f9).

# %%
for col in df.columns :
    if str(df[col].dtypes) != 'object' :
        plt.figure()
        df.boxplot(column=[col])
#df.plot(kind = 'box', subplots = True)
# Out:
# C:\Users\carl_\anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\carl_\anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\carl_\anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\carl_\anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\carl_\anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\carl_\anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\carl_\anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# You need to create boxplots and  histograms to evaluate the data for potential outliers or data anomalies. Generally, outliers are defined as observations that differ significantly from the other values in the dataset or feature.
#
# Reviewing the distribution of values by column will help you  interpret this. Outliers are extreme values that fall far outside the mean and standard deviation of a set of observations. They  can mislead the training process in building machine learning models. Outliers may be real anomalies in the observations or artificial errors.
#
# One method for outlier analysis is extreme value analysis using a boxplot, which assumes a normal distribution. The figure below describes the components of a boxplot. Notice the outlier is the point outside the upper whisker end.
#
# ![](AnnotatedBoxplot.png)
# <font color='teal'>Follow these steps:
#
# 1. Create boxplots - earlier step
# 2. Apply outlier removal using the Interquartile range or replacement
# 3. Review how many observations were removed</font>
#
# Hint: Recall from your statistics prework that a common definition of an outlier is an observation lying more than (1.5 * the Interquartile range) above the third quartile, or more than just that much below the first quartile.

# %%
# Let's get the Interquartile range, or IQR. This is equal to Q3 - Q1. 
# First, let's use the quantile() method to get the first quartile, and store it in a variable called Q1.
# We'll want to plug 0.25 into the quantile method. 
Q1 = df.quantile(.25)

# Now get Q3 and store in a variable called Q3. 
Q3 = df.quantile(.75)
# Now calculate the IQR, storing it in a variable called IQR.
IQR = Q3-Q1
# Make a variable called `dfno`, and assign it the value: df[~((df < (Q1 - 1.5 * IQR)) |(df> (Q3 + 1.5 * IQR))).any(axis=1)]. 
# This filters on our existing dataframe, picking out just those observations that are NOT outliers. 
dfno = df[~((df < (Q1 - 1.5 * IQR)) |(df> (Q3 + 1.5 * IQR))).any(axis=1)]

# We now want to make a boxplot of this new dataframe dfno. 
fgmp = dfno.boxplot(grid=False, vert=False,fontsize=15, figsize=(12,15))

# %%
# Print the shapes of our dataframes df and dfno to compare the number of observations in each. 
print(df.shape,dfno.shape)
# Out:
# (330, 29) (179, 29)

# %% [markdown]
# There are many ways to discover and remove outliers, and what counts as a sensible way of doing so depends on your problem, your methodology for solving that problem, and the nature of your data.
#
# Each method will have its merits and demerits. As we can see, in this instance, we've lost a great many observations!
#
# There is no hard and fast rule as to which outlier removal method is best in all cases, and you will have to exercise your good judgement in arriving at an appropriate method for your problem at hand. We will cover outlier removal in more depth in units 7 (Data Wrangling) and 10 (Statistics for Exploratory Data Analysis) of the course.

# %% [markdown]
# There are many possible response variables you could have identified in Step 1 of this guided capstone. However, for the rest of this guided capstone project, we will focus on increasing revenue by increasing the lift ticket prices and the number of days the resort is open per year. In this case, we need to investigate the expected lift ticket price for Big Mountain based on all the other given resort characteristics. In addition, we want to predict the number of days the resort will be open each season.

# %% [markdown]
# <font color='teal'>**Review the `AdultWeekday`,`AdultWeekend` response variable distributions**</font>

# %%
# Make a histogram of the 'AdultWeekday' column of the dfno dataframe. 
# You'll want to call hist() on that column 
dfno.hist('AdultWeekday')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002448B401F08>]],
#       dtype=object)

# %%
# Do the same but with the AdultWeekend column 
dfno.hist('AdultWeekend')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002448B0D7D88>]],
#       dtype=object)

# %% [markdown]
# <font color='teal'>**Review the `daysOpenLas

# %%
# Do the same as above! You got this :) 
dfno.hist('daysOpenLastYear')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002448B83B348>]],
#       dtype=object)

# %%
dfno.hist('projectedDaysOpen')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002448B4ACA88>]],
#       dtype=object)

# %% [markdown]
# After reviewing these respons varible distributions, there doesn't appear to be any data issues to mitigate. Now, we move on to investigating feature relationship and interactions between the features the response.

# %% [markdown]
# # Explore data relationships

# %% [markdown]
# <font color='teal'>**Create pairplots or what is commonly referred to as biplots**</font>
#
# Hint: pairplots are covered in this article on EDA [here](https://medium.com/@aiden.dataminer/the-data-science-method-dsm-exploratory-data-analysis-bc84d4d8d3f9).

# %%
sns.pairplot(dfno)

# %% [markdown]
# # Identification and creation of features

# %% [markdown]
# <font color='teal'>**Create a Pearson correlation heatmap**</font>

# %%
#Calculate the correlation coefficients
corr = dfno.corr()
#plot it in the next line
corr.round(2).style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\carl_\anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# C:\Users\carl_\anaconda3\lib\site-packages\pandas\io\formats\style.py:1089: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\Users\carl_\anaconda3\lib\site-packages\pandas\io\formats\style.py:1090: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
#     #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col1 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col2 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col3 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col8 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col10 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col11 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col12 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col13 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col14 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col15 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col16 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col17 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col18 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col19 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col20 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col21 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col22 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col23 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col24 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col25 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row0_col26 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col0 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col2 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col3 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col7 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col8 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col9 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col10 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col12 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col13 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col14 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col15 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col16 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col17 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col18 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col19 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col20 {
#             background-color:  #f29274;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col21 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col22 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col23 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col24 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col25 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row1_col26 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row2_col0 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row2_col1 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row2_col3 {
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_67a499f0_9bad_11ea_9dc4_d89c6761b9e2row2_col5 {
#             background-color:  #3b4cc0

# %% [markdown]
# When reviewing the Pearson correlation coefficient heatmap, you can see substantial differences in the correlations compared to the response variable(s) as well as in the features when compared to each other. The heatmap helps identify features that suffer from multi-collinearity.

# %% [markdown]
# <font color='teal'>**Use the correlation matrix displayed in the heatmap to select and remove collinear features. Remember to exclude the response variable(s) from the matrix to ensure they are retained in your final model development dataset. Then select those features that are more than 95% correlated for removal.**</font>
#
# Step 1: Create a correlation matrix that excludes your response variables.
#
# Step 2: Select the upper triangle of the correlation matrix. This is because a correlation matrix actually contains the same information, twice over!
#
# Step 3: Find the index of feature columns with a correlation greater than 0.95.

# %%
# Step 1. Call the variable corr_matrix
corr_matrix = dfno.drop(['AdultWeekday','AdultWeekend','daysOpenLastYear','projectedDaysOpen'], axis=1).corr().abs()

# Step 2. Uncomment the following code to get the upper triangle of the correlation matrix 
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Step 3. This code iterates through our columns and gets the index of any that have a correlation > 0.95
# Call the variable to_drop, get the columns of our 'upper' variable, make sure the threshold is 0.95.
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
# Let's see those features! 
print('Features selected to drop include:',to_drop)
# Out:
# Features selected to drop include: ['base_elev', 'calctot']

# %%
print('Reduced dataframe size: ',dfno.drop(dfno[to_drop], axis=1).shape)
# Out:
# Reduced dataframe size:  (179, 27)

# %%
# Now replace dfno by the result of dropping the columns in the to_drop variable from it
dfno.drop(to_drop, axis=1, inplace=True)
dfno.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179 entries, 1 to 329
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         179 non-null    int64
#  1   Name               179 non-null    object
#  2   state              179 non-null    object
#  3   summit_elev        179 non-null    int64
#  4   vertical_drop      179 non-null    int64
#  5   trams              179 non-null    int64
#  6   fastEight          179 non-null    float64
#  7   fastSixes          179 non-null    int64
#  8   fastQuads          179 non-null    int64
#  9   quad               179 non-null    int64
#  10  triple             179 non-null    int64
#  11  double             179 non-null    int64
#  12  surface            179 non-null    int64
#  13  total_chairs       179 non-null    int64
#  14  Runs               178 non-null    float64
#  15  TerrainParks       148 non-null    float64
#  16  LongestRun_mi      176 non-null    float64
#  17  SkiableTerrain_ac  178 non-null    float64
#  18  Snow Making_ac     155 non-null    float64
#  19  daysOpenLastYear   147 non-null    float64
#  20  yearsOpen          178 non-null    float64
#  21  averageSnowfall    173 non-null    float64
#  22  AdultWeekday       179 non-null    float64
#  23  AdultWeekend       178 non-null    float64
#  24  projectedDaysOpen  154 non-null    float64
#  25  NightSkiing_ac     179 non-null    float64
#  26  diff               179 non-null    float64
# dtypes: float64(14), int64(11), object(2)
# memory usage: 39.2+ KB
# C:\Users\carl_\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# Now we address the feature creation piece of this step. We can create additional features through many methods such as: combining several features, grouping features into bins, or even by applying an unsupervised classification algorithm, such as k-means clustering and using the clusters as features in our model development dataset.
#
# Clustering essentially finds patterns in data when we don't know in advance what we're looking for. The K-means algorithm is one way of doing clustering. It puts our data into groups (or 'clusters') which can then become features for further analysis. What the k-means algorithm outputs, though, depends on the number of clusters we set out to have. We will use a method called 'Elbow plotting' to determine this number.
#
# We will cover clustering and k-means thoroughly in the Unsupervised Learning unit of this course, but for now, we'll use it for feature creation alone, which is an integral part of Exploratory Data Analysis. Don't worry if you don't understand the details just yet.

# %% [markdown]
# Run the next two cells below to create an Elbow plot. The Elbow plot is a diagnostic tool that helps us determine the number of clusters to include in our k-means clustering implementation.
#
# In this example, the error between clusters and within clusters is compared for a range of 1 to 11 clusters, and it appears the elbow is between two and four, therefore we set the parameter k = 3.

# %%
dfno.dropna(inplace=True)
from sklearn.cluster import KMeans
x = dfno.drop(['Name','state'], axis =1).values
# Out:
# C:\Users\carl_\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
Error =[]
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i).fit(x)
    kmeans.fit(x)
    Error.append(kmeans.inertia_)
import matplotlib.pyplot as plt
plt.plot(range(1, 11), Error)
plt.title('Elbow method')
plt.xlabel('No of clusters')
plt.ylabel('Error')
plt.show()

# %% [markdown]
# <font color='teal'>**Fit the kmeans algorithm with the k parameter set to three and plot the results.**</font>

# %%
# This code will fit the k-means algorithm with our k parameter set to three, and plot the results. Cool, huh? 
kmeans3 = KMeans(n_clusters=3)
y_kmeans3 = kmeans3.fit_predict(x)
plt.scatter(x[:, 0], x[:, 1], c=y_kmeans3, s=50, cmap='viridis')

centers = kmeans3.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# <font color='teal'>**Add the clusters to your dataframe as a new column to include in the next step and write the updated dataframe out as csv. Save the dataframe in the data folder and name it `step3_output.csv`.**</font>

# %%
# Make a new column in your dfno dataframe called 'clusters', and assign it the variable: y_kmeans3
dfno['clusters'] = y_kmeans3
# Out:
# C:\Users\carl_\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dfno.info()
# Write your dataframe to csv 
dfno.to_csv('step3_output.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104 entries, 1 to 327
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         104 non-null    int64
#  1   Name               104 non-null    object
#  2   state              104 non-null    object
#  3   summit_elev        104 non-null    int64
#  4   vertical_drop      104 non-null    int64
#  5   trams              104 non-null    int64
#  6   fastEight          104 non-null    float64
#  7   fastSixes          104 non-null    int64
#  8   fastQuads          104 non-null    int64
#  9   quad               104 non-null    int64
#  10  triple             104 non-null    int64
#  11  double             104 non-null    int64
#  12  surface            104 non-null    int64
#  13  total_chairs       104 non-null    int64
#  14  Runs               104 non-null    float64
#  15  TerrainParks       104 non-null    float64
#  16  LongestRun_mi      104 non-null    float64
#  17  SkiableTerrain_ac  104 non-null    float64
#  18  Snow Making_ac     104 non-null    float64
#  19  daysOpenLastYear   104 non-null    float64
#  20  yearsOpen          104 non-null    float64
#  21  averageSnowfall    104 non-null    float64
#  22  AdultWeekday       104 non-null    float64
#  23  AdultWeekend       104 non-null    float64
#  24  projectedDaysOpen  104 non-null    float64
#  25  NightSkiing_ac     104 non-null    float64
#  26  diff               104 non-null    float64
#  27  clusters           104 non-null    int32
# dtypes: float64(14), int32(1), int64(11), object(2)
# memory usage: 23.2+ KB
